# %% [markdown]
# # Training a microWakeWord Model
#
# This notebook steps you through training a basic microWakeWord model. It is intended as a **starting point** for advanced users. You should use Python 3.10.
#
# **The model generated will most likely not be usable for everyday use; it may be difficult to trigger or falsely activates too frequently. You will most likely have to experiment with many different settings to obtain a decent model!**
#
# In the comment at the start of certain blocks, I note some specific settings to consider modifying.
#
# This runs on Google Colab, but is extremely slow compared to training on a local GPU. If you must use Colab, be sure to Change the runtime type to a GPU. Even then, it still slow!
#
# At the end of this notebook, you will be able to download a tflite file. To use this in ESPHome, you need to write a model manifest JSON file. See the [ESPHome documentation](https://esphome.io/components/micro_wake_word) for the details and the [model repo](https://github.com/esphome/micro-wake-word-models/tree/main/models/v2) for examples.

# %%
# Installs microWakeWord. Be sure to restart the session after this is finished.
import platform

if platform.system() == "Darwin":
    # `pymicro-features` is installed from a fork to support building on macOS
    # !pip install 'git+https://github.com/puddly/pymicro-features@puddly/minimum-cpp-version'

# `audio-metadata` is installed from a fork to unpin `attrs` from a version that breaks Jupyter
# !pip install 'git+https://github.com/whatsnowplaying/audio-metadata@d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f'

# !git clone https://github.com/kahrendt/microWakeWord
# !pip install -e ./microWakeWord
# Out:
# Collecting git+https://github.com/puddly/pymicro-features@puddly/minimum-cpp-version
#   Cloning https://github.com/puddly/pymicro-features (to revision puddly/minimum-cpp-version) to /private/var/folders/5h/7138qtm54kbg7ydv1khrd_5w0000gn/T/pip-req-build-22l2etay
#   Running command git clone --filter=blob:none --quiet https://github.com/puddly/pymicro-features /private/var/folders/5h/7138qtm54kbg7ydv1khrd_5w0000gn/T/pip-req-build-22l2etay
#   Running command git checkout -b puddly/minimum-cpp-version --track origin/puddly/minimum-cpp-version
#   Switched to a new branch 'puddly/minimum-cpp-version'
#   branch 'puddly/minimum-cpp-version' set up to track 'origin/puddly/minimum-cpp-version'.
#   Resolved https://github.com/puddly/pymicro-features to commit e1d3f88183e12bb8af2df9e399ea157af7393762
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pymicro_features
#   Building wheel for pymicro_features (pyproject.toml) ... done
#   Created wheel for pymicro_features: filename=pymicro_features-1.0.0-cp310-cp310-macosx_15_0_arm64.whl size=98721 sha256=ba96295bee4e48a837cfc769be3bd122c1ba36c8f61df69fd49854de7f75bb0e
#   Stored in directory: /private/var/folders/5h/7138qtm54kbg7ydv1khrd_5w0000gn/T/pip-ephem-wheel-cache-ymh043jt/wheels/d5/96/49/27dfe5844c34a6e8d0e8d6bae09248185d48efd6ad105eaf38
# Successfully built pymicro_features
# Installing collected packages: pymicro_features
# Successfully installed pymicro_features-1.0.0
# Collecting git+https://github.com/whatsnowplaying/audio-metadata@d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Cloning https://github.com/whatsnowplaying/audio-metadata (to revision d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f) to /private/var/folders/5h/7138qtm54kbg7ydv1khrd_5w0000gn/T/pip-req-build-nul6ckyo
#   Running command git clone --filter=blob:none --quiet https://github.com/whatsnowplaying/audio-metadata /private/var/folders/5h/7138qtm54kbg7ydv1khrd_5w0000gn/T/pip-req-build-nul6ckyo
#   Running command git rev-parse -q --verify 'sha^d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f'
#   Running command git fetch -q https://github.com/whatsnowplaying/audio-metadata d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Running command git checkout -q d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Resolved https://github.com/whatsnowplaying/audio-metadata to commit d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: attrs>=18.2 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from audio-metadata==0.12.0) (25.3.0)
# Collecting bidict==0.* (from audio-metadata==0.12.0)
#   Using cached bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting bitstruct<9.0,>=6.0 (from audio-metadata==0.12.0)
#   Downloading bitstruct-8.21.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting more-itertools<9.0,>=4.0 (from audio-metadata==0.12.0)
#   Using cached more_itertools-8.14.0-py3-none-any.whl.metadata (30 kB)
# Collecting pprintpp==0.* (from audio-metadata==0.12.0)
#   Using cached pprintpp-0.4.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Collecting wrapt<2.0,>=1.0 (from audio-metadata==0.12.0)
#   Downloading wrapt-1.17.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Using cached bidict-0.23.1-py3-none-any.whl (32 kB)
# Downloading bitstruct-8.21.0-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Using cached more_itertools-8.14.0-py3-none-any.whl (52 kB)
# Using cached pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Downloading wrapt-1.17.2-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Building wheels for collected packages: audio-metadata
#   Building wheel for audio-metadata (pyproject.toml) ... done
#   Created wheel for audio-metadata: filename=audio_metadata-0.12.0-py3-none-any.whl size=53140 sha256=a34115528497bcf5312ba29385bcd2da11069a1b7c715cb69f093f53bb67d314
#   Stored in directory: /Users/wouter/Library/Caches/pip/wheels/f4/b2/8a/fbabd46ecba2dcaf5e61b96554d26d00386d8ae2c2c4526ac9
# Successfully built audio-metadata
# Installing collected packages: pprintpp, wrapt, more-itertools, bitstruct, bidict, audio-metadata
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [audio-metadata]
# Successfully installed audio-metadata-0.12.0 bidict-0.23.1 bitstruct-8.21.0 more-itertools-8.14.0 pprintpp-0.4.0 wrapt-1.17.2
# Cloning into 'microWakeWord'...
# remote: Enumerating objects: 935, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 935 (delta 157), reused 136 (delta 136), pack-reused 752 (from 3)
# Receiving objects: 100% (935/935), 31.59 MiB | 36.47 MiB/s, done.
# Resolving deltas: 100% (596/596), done.
# Obtaining file:///Users/wouter/projects/microWakeWord/notebooks/microWakeWord
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting audiomentations (from microwakeword==0.1.0)
#   Downloading audiomentations-0.42.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: audio_metadata in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from microwakeword==0.1.0) (0.12.0)
# Collecting datasets (from microwakeword==0.1.0)
#   Downloading datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Collecting mmap_ninja (from microwakeword==0.1.0)
#   Downloading mmap_ninja-0.7.4-py3-none-any.whl.metadata (13 kB)
# Collecting numpy (from microwakeword==0.1.0)
#   Downloading numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: pymicro-features in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from microwakeword==0.1.0) (1.0.0)
# Requirement already satisfied: pyyaml in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from microwakeword==0.1.0) (6.0.2)
# Collecting tensorflow>=2.16 (from microwakeword==0.1.0)
#   Downloading tensorflow-2.19.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (4.0 kB)
# Collecting webrtcvad (from microwakeword==0.1.0)
#   Downloading webrtcvad-2.0.10.tar.gz (66 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting absl-py>=1.0.0 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading protobuf-5.29.5-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (2.32.4)
# Requirement already satisfied: setuptools in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Using cached termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (1.17.2)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading grpcio-1.73.1-cp310-cp310-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.19.0 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting numpy (from microwakeword==0.1.0)
#   Downloading numpy-2.1.3-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting h5py>=3.11.0 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading h5py-3.14.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading ml_dtypes-0.5.1-cp310-cp310-macosx_10_9_universal2.whl.metadata (21 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (2025.7.9)
# Collecting markdown>=2.6.8 (from tensorboard~=2.19.0->tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow>=2.16->microwakeword==0.1.0)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow>=2.16->microwakeword==0.1.0)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0)
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading optree-0.16.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (30 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow>=2.16->microwakeword==0.1.0) (3.0.2)
# Requirement already satisfied: attrs>=18.2 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (25.3.0)
# Requirement already satisfied: bidict==0.* in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (0.23.1)
# Requirement already satisfied: bitstruct<9.0,>=6.0 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (8.21.0)
# Requirement already satisfied: more-itertools<9.0,>=4.0 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (8.14.0)
# Requirement already satisfied: pprintpp==0.* in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (0.4.0)
# Collecting numpy-minmax<1,>=0.3.0 (from audiomentations->microwakeword==0.1.0)
#   Downloading numpy_minmax-0.5.0.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy-rms<1,>=0.4.2 (from audiomentations->microwakeword==0.1.0)
#   Downloading numpy_rms-0.6.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting librosa!=0.10.0,<0.12.0,>=0.8.0 (from audiomentations->microwakeword==0.1.0)
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting python-stretch<1,>=0.3.1 (from audiomentations->microwakeword==0.1.0)
#   Downloading python_stretch-0.3.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.7 kB)
# Collecting scipy<2,>=1.4 (from audiomentations->microwakeword==0.1.0)
#   Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting soxr<1.0.0,>=0.3.2 (from audiomentations->microwakeword==0.1.0)
#   Downloading soxr-0.5.0.post1-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Collecting audioread>=2.1.9 (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting numba>=0.51.0 (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0)
#   Downloading numba-0.61.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Collecting scikit-learn>=1.1.0 (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0)
#   Downloading scikit_learn-1.7.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting joblib>=1.0 (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: decorator>=4.3.0 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (5.2.1)
# Collecting soundfile>=0.12.1 (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0)
#   Downloading soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting lazy_loader>=0.1 (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0)
#   Using cached msgpack-1.1.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Requirement already satisfied: cffi>=1.0.0 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from numpy-minmax<1,>=0.3.0->audiomentations->microwakeword==0.1.0) (1.17.1)
# Requirement already satisfied: pycparser in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from cffi>=1.0.0->numpy-minmax<1,>=0.3.0->audiomentations->microwakeword==0.1.0) (2.22)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.51.0->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0)
#   Downloading llvmlite-0.44.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from pooch>=1.1->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (4.3.8)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.1.0->librosa!=0.10.0,<0.12.0,>=0.8.0->audiomentations->microwakeword==0.1.0)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from datasets->microwakeword==0.1.0)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pyarrow>=15.0.0 (from datasets->microwakeword==0.1.0)
#   Downloading pyarrow-20.0.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->microwakeword==0.1.0)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets->microwakeword==0.1.0)
#   Downloading pandas-2.3.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting tqdm>=4.66.3 (from datasets->microwakeword==0.1.0)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets->microwakeword==0.1.0)
#   Downloading xxhash-3.5.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->microwakeword==0.1.0)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting huggingface-hub>=0.24.0 (from datasets->microwakeword==0.1.0)
#   Downloading huggingface_hub-0.33.2-py3-none-any.whl.metadata (14 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0)
#   Downloading aiohttp-3.12.14-cp310-cp310-macosx_11_0_arm64.whl.metadata (7.6 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0)
#   Downloading frozenlist-1.7.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0)
#   Downloading multidict-6.6.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0)
#   Downloading propcache-0.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0)
#   Downloading yarl-1.20.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (73 kB)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub>=0.24.0->datasets->microwakeword==0.1.0)
#   Downloading hf_xet-1.1.5-cp37-abi3-macosx_11_0_arm64.whl.metadata (879 bytes)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from pandas->datasets->microwakeword==0.1.0) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets->microwakeword==0.1.0)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets->microwakeword==0.1.0)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.19.0-cp310-cp310-macosx_12_0_arm64.whl (252.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.5/252.5 MB 62.8 MB/s eta 0:00:0000:0100:01
# Downloading grpcio-1.73.1-cp310-cp310-macosx_11_0_universal2.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 77.8 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.1-cp310-cp310-macosx_10_9_universal2.whl (671 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.5/671.5 kB 34.4 MB/s eta 0:00:00
# Downloading numpy-2.1.3-cp310-cp310-macosx_14_0_arm64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 63.1 MB/s eta 0:00:00
# Downloading protobuf-5.29.5-cp38-abi3-macosx_10_9_universal2.whl (418 kB)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 60.9 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.14.0-cp310-cp310-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 65.7 MB/s eta 0:00:00
# Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 54.0 MB/s eta 0:00:00
# Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 75.5 MB/s eta 0:00:00a 0:00:01
# Downloading markdown-3.8.2-py3-none-any.whl (106 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-macosx_12_0_arm64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 52.2 MB/s eta 0:00:00
# Using cached termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading audiomentations-0.42.0-py3-none-any.whl (86 kB)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading numpy_rms-0.6.0-cp310-cp310-macosx_11_0_arm64.whl (10 kB)
# Downloading python_stretch-0.3.1-cp310-cp310-macosx_11_0_arm64.whl (76 kB)
# Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 72.3 MB/s eta 0:00:00a 0:00:01
# Downloading soxr-0.5.0.post1-cp310-cp310-macosx_11_0_arm64.whl (160 kB)
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached msgpack-1.1.1-cp310-cp310-macosx_11_0_arm64.whl (78 kB)
# Downloading numba-0.61.2-cp310-cp310-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 63.6 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp310-cp310-macosx_11_0_arm64.whl (26.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 78.4 MB/s eta 0:00:00a 0:00:01
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading scikit_learn-1.7.0-cp310-cp310-macosx_12_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 68.9 MB/s eta 0:00:00
# Downloading soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.1 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Downloading aiohttp-3.12.14-cp310-cp310-macosx_11_0_arm64.whl (466 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading multidict-6.6.3-cp310-cp310-macosx_11_0_arm64.whl (44 kB)
# Downloading yarl-1.20.1-cp310-cp310-macosx_11_0_arm64.whl (89 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.7.0-cp310-cp310-macosx_11_0_arm64.whl (46 kB)
# Downloading huggingface_hub-0.33.2-py3-none-any.whl (515 kB)
# Downloading hf_xet-1.1.5-cp37-abi3-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 43.7 MB/s eta 0:00:00
# Downloading propcache-0.3.2-cp310-cp310-macosx_11_0_arm64.whl (43 kB)
# Downloading pyarrow-20.0.0-cp310-cp310-macosx_12_0_arm64.whl (30.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 70.8 MB/s eta 0:00:0000:0100:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading mmap_ninja-0.7.4-py3-none-any.whl (14 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.16.0-cp310-cp310-macosx_11_0_arm64.whl (330 kB)
# Downloading pandas-2.3.1-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 76.3 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading xxhash-3.5.0-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
# Building wheels for collected packages: microwakeword, numpy-minmax, webrtcvad
#   Building editable for microwakeword (pyproject.toml) ... done
#   Created wheel for microwakeword: filename=microwakeword-0.1.0-0.editable-py3-none-any.whl size=9920 sha256=ffaf522cd4372919b0c3ad615682312eab9a95aa63ed07611011f5b97111780e
#   Stored in directory: /private/var/folders/5h/7138qtm54kbg7ydv1khrd_5w0000gn/T/pip-ephem-wheel-cache-9mvr489f/wheels/45/8d/0b/3cfb5ebe99566762602dd87aeea2ceee6369b22ff21956598f
#   Building wheel for numpy-minmax (pyproject.toml) ... done
#   Created wheel for numpy-minmax: filename=numpy_minmax-0.5.0-cp310-cp310-macosx_15_0_arm64.whl size=12213 sha256=90b8b331b5e980657c5b7e4f1083962dce01cfc0fbf06d7c9ba87492484e2f36
#   Stored in directory: /Users/wouter/Library/Caches/pip/wheels/9f/82/c6/9b42b65ee5685fbc4b453fe76ff34e0e6f6a7c6af2e8ef5b5a
#   Building wheel for webrtcvad (pyproject.toml) ... done
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp310-cp310-macosx_15_0_arm64.whl size=28521 sha256=fd8bf6ae310c479ee49550ae2a50b31193f33c896903837d36150ba139a420a8
#   Stored in directory: /Users/wouter/Library/Caches/pip/wheels/2a/2b/84/ac7bacfe8c68a87c1ee3dd3c66818a54c71599abf308e8eb35
# Successfully built microwakeword numpy-minmax webrtcvad
# Installing collected packages: webrtcvad, pytz, namex, libclang, flatbuffers, xxhash, wheel, werkzeug, tzdata, tqdm, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, python-stretch, pyarrow, protobuf, propcache, optree, opt-einsum, numpy, multidict, msgpack, mdurl, markdown, llvmlite, lazy_loader, joblib, hf-xet, grpcio, google-pasta, gast, fsspec, frozenlist, filelock, dill, audioread, async-timeout, aiohappyeyeballs, absl-py, yarl, tensorboard, soxr, soundfile, scipy, pooch, pandas, numpy-rms, numpy-minmax, numba, multiprocess, mmap_ninja, ml-dtypes, markdown-it-py, huggingface-hub, h5py, astunparse, aiosignal, scikit-learn, rich, aiohttp, librosa, keras, tensorflow, datasets, audiomentations, microwakeword
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67/67 [microwakeword]0m [datasets]w]n]ub]
# Successfully installed absl-py-2.3.1 aiohappyeyeballs-2.6.1 aiohttp-3.12.14 aiosignal-1.4.0 astunparse-1.6.3 async-timeout-5.0.1 audiomentations-0.42.0 audioread-3.0.1 datasets-4.0.0 dill-0.3.8 filelock-3.18.0 flatbuffers-25.2.10 frozenlist-1.7.0 fsspec-2025.3.0 gast-0.6.0 google-pasta-0.2.0 grpcio-1.73.1 h5py-3.14.0 hf-xet-1.1.5 huggingface-hub-0.33.2 joblib-1.5.1 keras-3.10.0 lazy_loader-0.4 libclang-18.1.1 librosa-0.11.0 llvmlite-0.44.0 markdown-3.8.2 markdown-it-py-3.0.0 mdurl-0.1.2 microwakeword-0.1.0 ml-dtypes-0.5.1 mmap_ninja-0.7.4 msgpack-1.1.1 multidict-6.6.3 multiprocess-0.70.16 namex-0.1.0 numba-0.61.2 numpy-2.1.3 numpy-minmax-0.5.0 numpy-rms-0.6.0 opt-einsum-3.4.0 optree-0.16.0 pandas-2.3.1 pooch-1.8.2 propcache-0.3.2 protobuf-5.29.5 pyarrow-20.0.0 python-stretch-0.3.1 pytz-2025.2 rich-14.0.0 scikit-learn-1.7.0 scipy-1.15.3 soundfile-0.13.1 soxr-0.5.0.post1 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 termcolor-3.1.0 threadpoolctl-3.6.0 tqdm-4.67.1 tzdata-2025.2 webrtcvad-2.0.10 werkzeug-3.1.3 wheel-0.45.1 xxhash-3.5.0 yarl-1.20.1

# %%
# Generates 1 sample of the target word for manual verification.

target_word = 'hey_bitch'  # Phonetic spellings may produce better samples

import os
import sys
import platform

from IPython.display import Audio

if not os.path.exists("./piper-sample-generator"):
    if platform.system() == "Darwin":
        # !git clone -b mps-support https://github.com/kahrendt/piper-sample-generator
    else:
        # !git clone https://github.com/rhasspy/piper-sample-generator

    # !wget -O piper-sample-generator/models/en_US-libritts_r-medium.pt 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'

    # Install system dependencies
    # !pip install torch torchaudio piper-phonemize-cross==1.2.1

    if "piper-sample-generator/" not in sys.path:
        sys.path.append("piper-sample-generator/")

# !python3 piper-sample-generator/generate_samples.py "{target_word}" \
--max-samples 1 \
--batch-size 1 \
--output-dir generated_samples

Audio("generated_samples/0.wav", autoplay=True)
# Out:
# /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages/webrtcvad.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# DEBUG:__main__:Loading /Users/wouter/projects/microWakeWord/notebooks/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:MPS available, using GPU
# /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages/torch/nn/functional.py:5209: UserWarning: MPS: The constant padding of more than 3 dimensions is not currently supported natively. It uses View Ops default implementation to run. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Pad.mm:465.)
#   return torch._C._nn.pad(input, pad, mode, value)
# DEBUG:__main__:Batch 1/1 complete
# INFO:__main__:Done
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Generates a larger amount of wake word samples.
# Start here when trying to improve your model.
# See https://github.com/rhasspy/piper-sample-generator for the full set of
# parameters. In particular, experiment with noise-scales and noise-scale-ws,
# generating negative samples similar to the wake word, and generating many more
# wake word samples, possibly with different phonetic pronunciations.

# !python3 piper-sample-generator/generate_samples.py "{target_word}" \
--max-samples 1000 \
--batch-size 100 \
--output-dir generated_samples
# Out:
# /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages/webrtcvad.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# DEBUG:__main__:Loading /Users/wouter/projects/microWakeWord/notebooks/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:MPS available, using GPU
# /Users/wouter/projects/microWakeWord/venv/lib/python3.10/site-packages/torch/nn/functional.py:5209: UserWarning: MPS: The constant padding of more than 3 dimensions is not currently supported natively. It uses View Ops default implementation to run. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Pad.mm:465.)
#   return torch._C._nn.pad(input, pad, mode, value)
# DEBUG:__main__:Batch 1/10 complete
# DEBUG:__main__:Batch 2/10 complete
# DEBUG:__main__:Batch 3/10 complete
# DEBUG:__main__:Batch 4/10 complete
# DEBUG:__main__:Batch 5/10 complete
# DEBUG:__main__:Batch 6/10 complete
# DEBUG:__main__:Batch 7/10 complete
# DEBUG:__main__:Batch 8/10 complete
# DEBUG:__main__:Batch 9/10 complete
# DEBUG:__main__:Batch 10/10 complete
# INFO:__main__:Done

# %%
# Downloads audio data for augmentation. This can be slow!
# Borrowed from openWakeWord's automatic_model_training.ipynb, accessed March 4, 2024
#
# **Important note!** The data downloaded here has a mixture of difference
# licenses and usage restrictions. As such, any custom models trained with this
# data should be considered as appropriate for **non-commercial** personal use only.

import datasets
import scipy
import os
import shutil
import librosa
import numpy as np

from pathlib import Path
from tqdm import tqdm

## Download MIR RIR data

shutil.rmtree("./mit_rirs", ignore_errors=True)
shutil.rmtree("./audioset", ignore_errors=True)
shutil.rmtree("./fma", ignore_errors=True)

output_dir = "./mit_rirs"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    
    # Load dataset with explicit Audio feature that doesn't use torchcodec
    rir_dataset = datasets.load_dataset(
        "davidscripka/MIT_environmental_impulse_responses", 
        split="train", 
        streaming=True
    ).cast_column("audio", datasets.Audio(decode=True))
    
    # Process the data
    for i, row in enumerate(tqdm(rir_dataset)):
        try:
            # Try to access audio data
            audio_data = row['audio']
            audio_array = audio_data['array']
            sample_rate = audio_data['sampling_rate']
            
            # Generate filename
            name = f"rir_audio_{i:06d}.wav"
            
            # Resample if needed
            if sample_rate != 16000:
                import librosa
                audio_array = librosa.resample(audio_array, orig_sr=sample_rate, target_sr=16000)
            
            # Convert to 16-bit PCM
            audio_int16 = (audio_array * 32767).astype(np.int16)
            
            # Save as wav file
            scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, audio_int16)
            
        except Exception as e:
            print(f"Error processing row {i}: {e}")
            continue

## Download noise and background audio

# Audioset Dataset (https://research.google.com/audioset/dataset/index.html)
# Download one part of the audioset .tar files, extract, and convert to 16khz
# For full-scale training, it's recommended to download the entire dataset from
# https://huggingface.co/datasets/agkphysics/AudioSet, and
# even potentially combine it with other background noise datasets (e.g., FSD50k, Freesound, etc.)

if not os.path.exists("audioset"):
    os.mkdir("audioset")

    fname = "bal_train09.tar"
    out_dir = f"audioset/{fname}"
    link = "https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/" + fname
    # !wget -O {out_dir} {link}
    # !cd audioset && tar -xf bal_train09.tar

    output_dir = "./audioset_16k"
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)

    # Use librosa directly instead of datasets Audio to avoid torchcodec issues
    audio_files = list(Path("audioset/audio").glob("**/*.flac"))
    for audio_file in tqdm(audio_files):
        try:
            # Load audio with librosa
            audio_array, sample_rate = librosa.load(str(audio_file), sr=16000)
            
            # Generate output filename
            name = audio_file.name.replace(".flac", ".wav")
            
            # Convert to 16-bit PCM
            audio_int16 = (audio_array * 32767).astype(np.int16)
            
            # Save as wav file
            scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, audio_int16)
            
        except Exception as e:
            print(f"Error processing {audio_file}: {e}")
            continue

# Free Music Archive dataset
# https://github.com/mdeff/fma
# (Third-party mchl914 extra small set)

output_dir = "./fma"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    fname = "fma_xs.zip"
    link = "https://huggingface.co/datasets/mchl914/fma_xsmall/resolve/main/" + fname
    out_dir = f"fma/{fname}"
    # !wget -O {out_dir} {link}
    # !cd {output_dir} && unzip -q {fname}

    output_dir = "./fma_16k"
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)

    # Use librosa directly instead of datasets Audio to avoid torchcodec issues
    audio_files = list(Path("fma/fma_small").glob("**/*.mp3"))
    for audio_file in tqdm(audio_files):
        try:
            # Load audio with librosa
            audio_array, sample_rate = librosa.load(str(audio_file), sr=16000)
            
            # Generate output filename
            name = audio_file.name.replace(".mp3", ".wav")
            
            # Convert to 16-bit PCM
            audio_int16 = (audio_array * 32767).astype(np.int16)
            
            # Save as wav file
            scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, audio_int16)
            
        except Exception as e:
            print(f"Error processing {audio_file}: {e}")
            continue
# Out:
# Resolving data files:   0%|          | 0/270 [00:00<?, ?it/s]
# 270it [00:37,  7.25it/s]
# --2025-07-11 11:13:16--  https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/bal_train09.tar
# Resolving huggingface.co (huggingface.co)... 18.239.50.16, 18.239.50.80, 18.239.50.49, ...
# Connecting to huggingface.co (huggingface.co)|18.239.50.16|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.hf.co/repos/be/e0/bee0f1da8c82b29f9518546133bb1ea7f58db75f059d5dc36fc0c28464d5386c/9ab88550e77c8289acf71d19ae3f254fadad16f3cea305ef08a16949a928acf9?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27bal_train09.tar%3B+filename%3D%22bal_train09.tar%22%3B&response-content-type=application%2Fx-tar&Expires=1752228796&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=BJrZxyxHBf9RTq4G9o%7Ecv4BppDlqPyTi7zGUK1T9Ds7cM%7EEi2Hbb60PdW73RwLatfW-bk-Pr%7EjN%7EPF2pzOEWiJzabyXCvyTlYqeEsDE-q44WHDR5XRxU1SfzP%7ESfz8v6i8v8sIoc2FIR0vglddJTPPuzJfT4Ssosrul-yQ2doOlXr9CFop6OX6KDcw2XTUg-fzpaJgiCKSACoNiH8hqGKfYFfX7pw5Ia5QZWc4VqOCK74WjXa4jNiRMn%7Ex7TZKUZeQDIfxws7tWB6jlTYOFKnT-6SLBdW5pQ8LnA%7EKQnIL1QZ0Qvk4HQ8sM7ZE9lJoaiZUzWv6y94KGhNGB8jZ46iw__&Key-Pair-Id=K3RPWS32NSSJCE [following]
# --2025-07-11 11:13:16--  https://cdn-lfs.hf.co/repos/be/e0/bee0f1da8c82b29f9518546133bb1ea7f58db75f059d5dc36fc0c28464d5386c/9ab88550e77c8289acf71d19ae3f254fadad16f3cea305ef08a16949a928acf9?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27bal_train09.tar%3B+filename%3D%22bal_train09.tar%22%3B&response-content-type=application%2Fx-tar&Expires=1752228796&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=BJrZxyxHBf9RTq4G9o%7Ecv4BppDlqPyTi7zGUK1T9Ds7cM%7EEi2Hbb60PdW73RwLatfW-bk-Pr%7EjN%7EPF2pzOEWiJzabyXCvyTlYqeEsDE-q44WHDR5XRxU1SfzP%7ESfz8v6i8v8sIoc2FIR0vglddJTPPuzJfT4Ssosrul-yQ2doOlXr9CFop6OX6KDcw2XTUg-fzpaJgiCKSACoNiH8hqGKfYFfX7pw5Ia5QZWc4VqOCK74WjXa4jNiRMn%7Ex7TZKUZeQDIfxws7tWB6jlTYOFKnT-6SLBdW5pQ8LnA%7EKQnIL1QZ0Qvk4HQ8sM7ZE9lJoaiZUzWv6y94KGhNGB8jZ46iw__&Key-Pair-Id=K3RPWS32NSSJCE
# Resolving cdn-lfs.hf.co (cdn-lfs.hf.co)... 18.239.83.31, 18.239.83.30, 18.239.83.10, ...
# Connecting to cdn-lfs.hf.co (cdn-lfs.hf.co)|18.239.83.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 968540160 (924M) [application/x-tar]
# Saving to: ‘audioset/bal_train09.tar’
#
# audioset/bal_train0 100%[===================>] 923,67M  71,3MB/s    in 12s
#
# 2025-07-11 11:13:28 (78,0 MB/s) - ‘audioset/bal_train09.tar’ saved [968540160/968540160]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 685/685 [00:09<00:00, 71.07it/s]
# --2025-07-11 11:13:40--  https://huggingface.co/datasets/mchl914/fma_xsmall/resolve/main/fma_xs.zip
# Resolving huggingface.co (huggingface.co)... 18.239.50.16, 18.239.50.80, 18.239.50.49, ...
# Connecting to huggingface.co (huggingface.co)|18.239.50.16|:443... connected.
# HTTP request sent, awaiting response...
# 302 Found
# Location: https://cdn-lfs-us-1.hf.co/repos/b6/94/b6949420efe7987c075219703fbd5649e8e30f4aa4783eb019be14dfc9e7f52e/e5876c13cfb0f7ef668327c75d1c40bc4a2ed9d5b8e62ce383d093319c9ff663?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27fma_xs.zip%3B+filename%3D%22fma_xs.zip%22%3B&response-content-type=application%2Fzip&Expires=1752228820&Policy=...&Signature=r7fLQIkoWHN3Ci2wybkyn3kjV5Om2N4bNygJuH4LNb6Yg6AoCK18S5b7AtCV8b2smvZhudj-y2r93TZlQJ6ktCwpSeNIqZUwGWzeh53NfuP7CaQkrjAbZQc2e2Ou4GJ93ZM-wj4pwzJDQXrGLbNNSl3g0w3QSIempO8BUiO6b0b2IQUtvxOVtj%7EDamXCzsKFEGHHge38OXlQXMVCm1egNPkdwT%7ExnPDanliW4MXf5pj3Wg6VTy8DYmhBkuJ%7EyPUPGcxWA11TQzYLS5IgPWmdZark8yr6syDooLK5dSzYbNyXeZ19a0hxiSlF6BLYMCV20gipa8CTNfO0wu2yy%7EZztQ__&Key-Pair-Id=K24J24Z295AEI9 [following]
# --2025-07-11 11:13:40--  https://cdn-lfs-us-1.hf.co/repos/b6/94/b6949420efe7987c075219703fbd5649e8e30f4aa4783eb019be14dfc9e7f52e/e5876c13cfb0f7ef668327c75d1c40bc4a2ed9d5b8e62ce383d093319c9ff663?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27fma_xs.zip%3B+filename%3D%22fma_xs.zip%22%3B&response-content-type=application%2Fzip&Expires=1752228820&Policy=...&Signature=r7fLQIkoWHN3Ci2wybkyn3kjV5Om2N4bNygJuH4LNb6Yg6AoCK18S5b7AtCV8b2smvZhudj-y2r93TZlQJ6ktCwpSeNIqZUwGWzeh53NfuP7CaQkrjAbZQc2e2Ou4GJ93ZM-wj4pwzJDQXrGLbNNSl3g0w3QSIempO8BUiO6b0b2IQUtvxOVtj%7EDamXCzsKFEGHHge38OXlQXMVCm1egNPkdwT%7ExnPDanliW4MXf5pj3Wg6VTy8DYmhBkuJ%7EyPUPGcxWA11TQzYLS5IgPWmdZark8yr6syDooLK5dSzYbNyXeZ19a0hxiSlF6BLYMCV20gipa8CTNfO0wu2yy%7EZztQ__&Key-Pair-Id=K24J24Z295AEI9
# Resolving cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)... 18.239.36.68, 18.239.36.126, 18.239.36.72, ...
# Connecting to cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)|18.239.36.68|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182339695 (174M) [application/zip]
# Saving to: ‘fma/fma_xs.zip’
#
# fma/fma_xs.zip      100%[===================>] 173,89M  68,5MB/s    in 2,5s
#
# 2025-07-11 11:13:43 (68,5 MB/s) - ‘fma/fma_xs.zip’ saved [182339695/182339695]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 210/210 [00:07<00:00, 29.09it/s]

# %%
# Sets up the augmentations.
# To improve your model, experiment with these settings and use more sources of
# background clips.

from microwakeword.audio.augmentation import Augmentation
from microwakeword.audio.clips import Clips
from microwakeword.audio.spectrograms import SpectrogramGeneration

clips = Clips(input_directory='generated_samples',
              file_pattern='*.wav',
              max_clip_duration_s=None,
              remove_silence=False,
              random_split_seed=10,
              split_count=0.1,
              )
augmenter = Augmentation(augmentation_duration_s=3.2,
                         augmentation_probabilities = {
                                "SevenBandParametricEQ": 0.1,
                                "TanhDistortion": 0.1,
                                "PitchShift": 0.1,
                                "BandStopFilter": 0.1,
                                "AddColorNoise": 0.1,
                                "AddBackgroundNoise": 0.75,
                                "Gain": 1.0,
                                "RIR": 0.5,
                            },
                         impulse_paths = ['mit_rirs'],
                         background_paths = ['fma_16k', 'audioset_16k'],
                         background_min_snr_db = -5,
                         background_max_snr_db = 10,
                         min_jitter_s = 0.195,
                         max_jitter_s = 0.205,
                         )
# Out:
# UserWarning:
#     pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %%
# Augment a random clip and play it back to verify it works well

from IPython.display import Audio
from microwakeword.audio.audio_utils import save_clip

random_clip = clips.get_random_clip()
augmented_clip = augmenter.augment_clip(random_clip)
save_clip(augmented_clip, 'augmented_clip.wav')

Audio("augmented_clip.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Augment samples and save the training, validation, and testing sets.
# Validating and testing samples generated the same way can make the model
# benchmark better than it performs in real-word use. Use real samples or TTS
# samples generated with a different TTS engine to potentially get more accurate
# benchmarks.

import os
from mmap_ninja.ragged import RaggedMmap

output_dir = 'generated_augmented_features'

if not os.path.exists(output_dir):
    os.mkdir(output_dir)

splits = ["training", "validation", "testing"]
for split in splits:
  out_dir = os.path.join(output_dir, split)
  if not os.path.exists(out_dir):
      os.mkdir(out_dir)


  split_name = "train"
  repetition = 2

  spectrograms = SpectrogramGeneration(clips=clips,
                                     augmenter=augmenter,
                                     slide_frames=10,    # Uses the same spectrogram repeatedly, just shifted over by one frame. This simulates the streaming inferences while training/validating in nonstreaming mode.
                                     step_ms=10,
                                     )
  if split == "validation":
    split_name = "validation"
    repetition = 1
  elif split == "testing":
    split_name = "test"
    repetition = 1
    spectrograms = SpectrogramGeneration(clips=clips,
                                     augmenter=augmenter,
                                     slide_frames=1,    # The testing set uses the streaming version of the model, so no artificial repetition is necessary
                                     step_ms=10,
                                     )

  RaggedMmap.from_generator(
      out_dir=os.path.join(out_dir, 'wakeword_mmap'),
      sample_generator=spectrograms.spectrogram_generator(split=split_name, repeat=repetition),
      batch_size=100,
      verbose=True,
  )
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
# Downloads pre-generated spectrogram features (made for microWakeWord in
# particular) for various negative datasets. This can be slow!

output_dir = './negative_datasets'
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    link_root = "https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/"
    filenames = ['dinner_party.zip', 'dinner_party_eval.zip', 'no_speech.zip', 'speech.zip']
    for fname in filenames:
        link = link_root + fname

        zip_path = f"negative_datasets/{fname}"
        # !wget -O {zip_path} {link}
        # !unzip -q {zip_path} -d {output_dir}
# Out:
# --2025-07-11 11:15:45--  https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/dinner_party.zip
# Resolving huggingface.co (huggingface.co)... 18.239.50.80, 18.239.50.49, 18.239.50.16, ...
# Connecting to huggingface.co (huggingface.co)|18.239.50.80|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/18a0885d595ced7faa73736a8680206f5ba6e80113ca3e6ce43130e510aac18f?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27dinner_party.zip%3B+filename%3D%22dinner_party.zip%22%3B&response-content-type=application%2Fzip&Expires=1752228946&Policy=...&Signature=ire3qC2JKPD2kwSBShf5dKgdeZE8e6JPL%7EWersRIfij8x4Cy%7E%7E7C6T%7EKysgERalu8Y3iIZ5Qk1dVPxTLt037t7QIzPKhM-9lr2irX8aaq4Ecek6Nw5tHgLAo-yJ5K%7E71N2KnVAcynK0dxtR3f9dMGquuI4SqVZ-T5XVzrzbckcOnVMmTFyzJTcz4DBJapuTdBxI2U-4wivrkD%7E2LU%7Eg5WT8YGcHFehSyldg3MFiqck0McNhRrvo9iVhBG5dHJT7m7hIPZis5SgaSW8AoU71uj9M9%7EdsvtpcnhQWGhSumN8afLFLe7o7rnSRBECTzWEXpsE21Ysmpxd27UAPh2KyJuA__&Key-Pair-Id=K24J24Z295AEI9 [following]
# --2025-07-11 11:15:46--  https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/18a0885d595ced7faa73736a8680206f5ba6e80113ca3e6ce43130e510aac18f?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27dinner_party.zip%3B+filename%3D%22dinner_party.zip%22%3B&response-content-type=application%2Fzip&Expires=1752228946&Policy=...&Signature=ire3qC2JKPD2kwSBShf5dKgdeZE8e6JPL%7EWersRIfij8x4Cy%7E%7E7C6T%7EKysgERalu8Y3iIZ5Qk1dVPxTLt037t7QIzPKhM-9lr2irX8aaq4Ecek6Nw5tHgLAo-yJ5K%7E71N2KnVAcynK0dxtR3f9dMGquuI4SqVZ-T5XVzrzbckcOnVMmTFyzJTcz4DBJapuTdBxI2U-4wivrkD%7E2LU%7Eg5WT8YGcHFehSyldg3MFiqck0McNhRrvo9iVhBG5dHJT7m7hIPZis5SgaSW8AoU71uj9M9%7EdsvtpcnhQWGhSumN8afLFLe7o7rnSRBECTzWEXpsE21Ysmpxd27UAPh2KyJuA__&Key-Pair-Id=K24J24Z295AEI9
# Resolving cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)... 13.227.219.46, 13.227.219.100, 13.227.219.75, ...
# Connecting to cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)|13.227.219.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 444310142 (424M) [application/zip]
# Saving to: ‘negative_datasets/dinner_party.zip’
#
# negative_datasets/d 100%[===================>] 423,73M  70,3MB/s    in 6,1s
#
# 2025-07-11 11:15:52 (69,3 MB/s) - ‘negative_datasets/dinner_party.zip’ saved [444310142/444310142]
#
# --2025-07-11 11:16:07--  https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/dinner_party_eval.zip
# Resolving huggingface.co (huggingface.co)... 18.239.50.80, 18.239.50.49, 18.239.50.16, ...
# Connecting to huggingface.co (huggingface.co)|18.239.50.80|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/e08e23a5e654dd4415a1c41a4b6cd02d1f983c821512367ad937bac1aeed8299?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27dinner_party_eval.zip%3B+filename%3D%22dinner_party_eval.zip%22%3B&response-content-type=application%2Fzip&Expires=1752228967&Policy=...&Signature=kE2HQwff4UXin2XuaVc2KTVHoacnsUfRQwuKUzFvmQBgzDckb9pzAzvIrtrR5U-q7buYPs6nO8odmaSlxkndZiA3qnBmZVLHqkph5mAPzIUP5QcM3HPa1EVPuU2jMz-A-4CJQHmrFLaSIBzGeQCKsH3cxC%7EITCER8HKRS95nmjNad7imlSVXaiXNsR%7EE5n3nd3gnDmtLvmF3Z9EXiX7OUUvICXjUBdFo4hgjUzzpSO5aMdUTUo2897yWZl53eKDbvq7oRWUmOWAbARpruncT%7EicySuxFu0G7WbWYTTlShjNWrRTUkvwLDf-tNymNUx0VLrFBgDdeoXY5KoArz7morg__&Key-Pair-Id=K24J24Z295AEI9 [following]
# --2025-07-11 11:16:07--  https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/e08e23a5e654dd4415a1c41a4b6cd02d1f983c821512367ad937bac1aeed8299?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27dinner_party_eval.zip%3B+filename%3D%22dinner_party_eval.zip%22%3B&response-content-type=application%2Fzip&Expires=1752228967&Policy=...&Signature=kE2HQwff4UXin2XuaVc2KTVHoacnsUfRQwuKUzFvmQBgzDckb9pzAzvIrtrR5U-q7buYPs6nO8odmaSlxkndZiA3qnBmZVLHqkph5mAPzIUP5QcM3HPa1EVPuU2jMz-A-4CJQHmrFLaSIBzGeQCKsH3cxC%7EITCER8HKRS95nmjNad7imlSVXaiXNsR%7EE5n3nd3gnDmtLvmF3Z9EXiX7OUUvICXjUBdFo4hgjUzzpSO5aMdUTUo2897yWZl53eKDbvq7oRWUmOWAbARpruncT%7EicySuxFu0G7WbWYTTlShjNWrRTUkvwLDf-tNymNUx0VLrFBgDdeoXY5KoArz7morg__&Key-Pair-Id=K24J24Z295AEI9
# Resolving cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)... 13.227.219.46, 13.227.219.100, 13.227.219.75, ...
# Connecting to cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)|13.227.219.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82329019 (79M) [application/zip]
# Saving to: ‘negative_datasets/dinner_party_eval.zip’
#
# negative_datasets/d 100%[===================>]  78,51M  75,9MB/s    in 1,0s
#
# 2025-07-11 11:16:08 (75,9 MB/s) - ‘negative_datasets/dinner_party_eval.zip’ saved [82329019/82329019]
#
# --2025-07-11 11:16:11--  https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/no_speech.zip
# Resolving huggingface.co (huggingface.co)... 18.239.50.80, 18.239.50.49, 18.239.50.16, ...
# Connecting to huggingface.co (huggingface.co)|18.239.50.80|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/722dbcc967275c64c9581ecb85729549830a9094ce605ee22b2ddab9dbabf3c8?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27no_speech.zip%3B+filename%3D%22no_speech.zip%22%3B&response-content-type=application%2Fzip&Expires=1752228971&Policy=...&Signature=dh0fR9NvsU8Yw4dFAvuvmfiWjwpZu3aOsafnGa8dIEy89Gn%7EKP8let8AlvGlilZjhE0Cb2UFM%7Elu5V0U8Weifj0dZIJCVjdmvOaHG-wTEywlgvehQSZGpxaM%7EHVQQ1Xd-yxDm6ipGZ6NO2CxC-LLsxgqeSwbCIYbx8arvGhbJV6ZJZRglJUhWCIccOxpeK8%7EVVsgIb12nYDXNNFJ4fIHNYs8q-zme%7ErrBChjgY4brLkpr2B-F4BdvWS5n1ImOf07lgGimPWYM7YL9VWkPP-JOo8buwrtKTbm9C6rmbvh9HxAkvYIxXPtbGX4FFWqg1ZiYyhhwrodUnsko7dFwi6MZw__&Key-Pair-Id=K24J24Z295AEI9 [following]
# --2025-07-11 11:16:11--  https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/722dbcc967275c64c9581ecb85729549830a9094ce605ee22b2ddab9dbabf3c8?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27no_speech.zip%3B+filename%3D%22no_speech.zip%22%3B&response-content-type=application%2Fzip&Expires=1752228971&Policy=...&Signature=dh0fR9NvsU8Yw4dFAvuvmfiWjwpZu3aOsafnGa8dIEy89Gn%7EKP8let8AlvGlilZjhE0Cb2UFM%7Elu5V0U8Weifj0dZIJCVjdmvOaHG-wTEywlgvehQSZGpxaM%7EHVQQ1Xd-yxDm6ipGZ6NO2CxC-LLsxgqeSwbCIYbx8arvGhbJV6ZJZRglJUhWCIccOxpeK8%7EVVsgIb12nYDXNNFJ4fIHNYs8q-zme%7ErrBChjgY4brLkpr2B-F4BdvWS5n1ImOf07lgGimPWYM7YL9VWkPP-JOo8buwrtKTbm9C6rmbvh9HxAkvYIxXPtbGX4FFWqg1ZiYyhhwrodUnsko7dFwi6MZw__&Key-Pair-Id=K24J24Z295AEI9
# Resolving cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)... 13.227.219.46, 13.227.219.100, 13.227.219.75, ...
# Connecting to cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)|13.227.219.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2000317854 (1,9G) [application/zip]
# Saving to: ‘negative_datasets/no_speech.zip’
#
# negative_datasets/n 100%[===================>]   1,86G  79,9MB/s    in 24s
#
# 2025-07-11 11:16:35 (79,2 MB/s) - ‘negative_datasets/no_speech.zip’ saved [2000317854/2000317854]
#
# --2025-07-11 11:17:32--  https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/speech.zip
# Resolving huggingface.co (huggingface.co)... 18.239.50.103, 18.239.50.80, 18.239.50.49, ...
# Connecting to huggingface.co (huggingface.co)|18.239.50.103|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/68b6b811b347b8321169f9e75ea2b9be73245943b4470af9532ca288d9f1b3cc?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27speech.zip%3B+filename%3D%22speech.zip%22%3B&response-content-type=application%2Fzip&Expires=1752229052&Policy=...&Signature=bM5eoURhpCN529m5Sgo8abwvXIEQqhhQrpqcPzc-ZlbUlt5Z62S2E8VDpaOQD4g0zUciWDl-wttrPi0TX7SBWwOObxacnrW1N1CkNYsURBgcyqzoWbwP-H2zAgEVsegbbM0qdqH9JASQTvLumvEggIqM6XQkkADQLa6CuOFbJKNmgqZNdjFGt0aXIe04GvovGz6fAHcqZgw0v9zwnaNJ5AuRzshRiVCrCWbH-qTBNyLQrjL0oYDfNiyEo1MmX9U1mvmwBCmn-wFGMHTDEU9K5PgrP4T7%7E1ZfjjkIPyit3rG1cLnWVjqpqS%7EeVA4pBFQKRJ8Y524viCEcdz-sIxuNcg__&Key-Pair-Id=K24J24Z295AEI9 [following]
# --2025-07-11 11:17:32--  https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/68b6b811b347b8321169f9e75ea2b9be73245943b4470af9532ca288d9f1b3cc?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27speech.zip%3B+filename%3D%22speech.zip%22%3B&response-content-type=application%2Fzip&Expires=1752229052&Policy=...&Signature=bM5eoURhpCN529m5Sgo8abwvXIEQqhhQrpqcPzc-ZlbUlt5Z62S2E8VDpaOQD4g0zUciWDl-wttrPi0TX7SBWwOObxacnrW1N1CkNYsURBgcyqzoWbwP-H2zAgEVsegbbM0qdqH9JASQTvLumvEggIqM6XQkkADQLa6CuOFbJKNmgqZNdjFGt0aXIe04GvovGz6fAHcqZgw0v9zwnaNJ5AuRzshRiVCrCWbH-qTBNyLQrjL0oYDfNiyEo1MmX9U1mvmwBCmn-wFGMHTDEU9K5PgrP4T7%7E1ZfjjkIPyit3rG1cLnWVjqpqS%7EeVA4pBFQKRJ8Y524viCEcdz-sIxuNcg__&Key-Pair-Id=K24J24Z295AEI9
# Resolving cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)... 18.65.39.65, 18.65.39.117, 18.65.39.32, ...
# Connecting to cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)|18.65.39.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3183001091 (3,0G) [application/zip]
# Saving to: ‘negative_datasets/speech.zip’
#
# negative_datasets/s 100%[===================>]   2,96G  74,4MB/s    in 40s
#
# 2025-07-11 11:18:11 (76,6 MB/s) - ‘negative_datasets/speech.zip’ saved [3183001091/3183001091]

# %%
# Save a yaml config that controls the training process
# These hyperparamters can make a huge different in model quality.
# Experiment with sampling and penalty weights and increasing the number of
# training steps.

import yaml
import os

config = {}

config["window_step_ms"] = 10

config["train_dir"] = (
    "trained_models/wakeword"
)


# Each feature_dir should have at least one of the following folders with this structure:
#  training/
#    ragged_mmap_folders_ending_in_mmap
#  testing/
#    ragged_mmap_folders_ending_in_mmap
#  testing_ambient/
#    ragged_mmap_folders_ending_in_mmap
#  validation/
#    ragged_mmap_folders_ending_in_mmap
#  validation_ambient/
#    ragged_mmap_folders_ending_in_mmap
#
#  sampling_weight: Weight for choosing a spectrogram from this set in the batch
#  penalty_weight: Penalizing weight for incorrect predictions from this set
#  truth: Boolean whether this set has positive samples or negative samples
#  truncation_strategy = If spectrograms in the set are longer than necessary for training, how are they truncated
#       - random: choose a random portion of the entire spectrogram - useful for long negative samples
#       - truncate_start: remove the start of the spectrogram
#       - truncate_end: remove the end of the spectrogram
#       - split: Split the longer spectrogram into separate spectrograms offset by 100 ms. Only for ambient sets

config["features"] = [
    {
        "features_dir": "generated_augmented_features",
        "sampling_weight": 2.0,
        "penalty_weight": 1.0,
        "truth": True,
        "truncation_strategy": "truncate_start",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/speech",
        "sampling_weight": 10.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/dinner_party",
        "sampling_weight": 10.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/no_speech",
        "sampling_weight": 5.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    { # Only used for validation and testing
        "features_dir": "negative_datasets/dinner_party_eval",
        "sampling_weight": 0.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "split",
        "type": "mmap",
    },
]

# Number of training steps in each iteration - various other settings are configured as lists that corresponds to different steps
config["training_steps"] = [10000]

# Penalizing weight for incorrect class predictions - lists that correspond to training steps
config["positive_class_weight"] = [1]
config["negative_class_weight"] = [20]

config["learning_rates"] = [
    0.001,
]  # Learning rates for Adam optimizer - list that corresponds to training steps
config["batch_size"] = 128

config["time_mask_max_size"] = [
    0
]  # SpecAugment - list that corresponds to training steps
config["time_mask_count"] = [0]  # SpecAugment - list that corresponds to training steps
config["freq_mask_max_size"] = [
    0
]  # SpecAugment - list that corresponds to training steps
config["freq_mask_count"] = [0]  # SpecAugment - list that corresponds to training steps

config["eval_step_interval"] = (
    500  # Test the validation sets after every this many steps
)
config["clip_duration_ms"] = (
    1500  # Maximum length of wake word that the streaming model will accept
)

# The best model weights are chosen first by minimizing the specified minimization metric below the specified target_minimization
# Once the target has been met, it chooses the maximum of the maximization metric. Set 'minimization_metric' to None to only maximize
# Available metrics:
#   - "loss" - cross entropy error on validation set
#   - "accuracy" - accuracy of validation set
#   - "recall" - recall of validation set
#   - "precision" - precision of validation set
#   - "false_positive_rate" - false positive rate of validation set
#   - "false_negative_rate" - false negative rate of validation set
#   - "ambient_false_positives" - count of false positives from the split validation_ambient set
#   - "ambient_false_positives_per_hour" - estimated number of false positives per hour on the split validation_ambient set
config["target_minimization"] = 0.9
config["minimization_metric"] = None  # Set to None to disable

config["maximization_metric"] = "average_viable_recall"

with open(os.path.join("training_parameters.yaml"), "w") as file:
    documents = yaml.dump(config, file)

# %%
# Trains a model. When finished, it will quantize and convert the model to a
# streaming version suitable for on-device detection.
# It will resume if stopped, but it will start over at the configured training
# steps in the yaml file.
# Change --train 0 to only convert and test the best-weighted model.
# On Google colab, it doesn't print the mini-batch results, so it may appear
# stuck for several minutes! Additionally, it is very slow compared to training
# on a local GPU.

# !python -m microwakeword.model_train_eval \
--training_config='training_parameters.yaml' \
--train 1 \
--restore_checkpoint 1 \
--test_tf_nonstreaming 0 \
--test_tflite_nonstreaming 0 \
--test_tflite_nonstreaming_quantized 0 \
--test_tflite_streaming 0 \
--test_tflite_streaming_quantized 1 \
--use_weights "best_weights" \
mixednet \
--pointwise_filters "64,64,64,64" \
--repeat_in_block  "1, 1, 1, 1" \
--mixconv_kernel_sizes '[5], [7,11], [9,15], [23]' \
--residual_connection "0,0,0,0" \
--first_conv_filters 32 \
--first_conv_kernel_size 5 \
--stride 3
# Out:
# UserWarning:
#     pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# INFO:absl:Loading and analyzing data sets.
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 4
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 10
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 14
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 22
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 16
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (128, 204, 40)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims         │ (128, 204, 1, 40) │          0 │ input_layer[0][0] │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream (Stream)     │ (128, 67, 1, 32)  │      6,400 │ expand_dims[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (128, 67, 1, 32)  │          0 │ stream[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_1 (Stream)   │ (128, 67, 1, 32)  │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (128, 63, 1, 32)  │        192 │ stream_1[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (128, 63, 1, 64)  │      2,048 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (128, 63, 1, 64)  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (128, 63, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_2 (Stream)   │ (128, 63, 1, 64)  │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split       │ [(128, 63, 1,     │          0 │ stream_2[0][0]    │
# │ (ChannelSplit)      │ 32), (128, 63, 1, │            │                   │
# │                     │ 32)]              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep        │ (128, 63, 1, 32)  │          0 │ channel_split[0]… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_1      │ (128, 63, 1, 32)  │          0 │ channel_split[0]… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (128, 57, 1, 32)  │        256 │ strided_keep[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (128, 53, 1, 32)  │        384 │ strided_keep_1[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop        │ (128, 53, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_1      │ (128, 53, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (128, 53, 1, 64)  │          0 │ strided_drop[0][… │
# │ (Concatenate)       │                   │            │ strided_drop_1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (128, 53, 1, 64)  │      4,096 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (128, 53, 1, 64)  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (128, 53, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_3 (Stream)   │ (128, 53, 1, 64)  │          0 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_1     │ [(128, 53, 1,     │          0 │ stream_3[0][0]    │
# │ (ChannelSplit)      │ 32), (128, 53, 1, │            │                   │
# │                     │ 32)]              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_2      │ (128, 53, 1, 32)  │          0 │ channel_split_1[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_3      │ (128, 53, 1, 32)  │          0 │ channel_split_1[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_3  │ (128, 45, 1, 32)  │        320 │ strided_keep_2[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4  │ (128, 39, 1, 32)  │        512 │ strided_keep_3[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_2      │ (128, 39, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_3      │ (128, 39, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (128, 39, 1, 64)  │          0 │ strided_drop_2[0… │
# │ (Concatenate)       │                   │            │ strided_drop_3[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (128, 39, 1, 64)  │      4,096 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (128, 39, 1, 64)  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (128, 39, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_4 (Stream)   │ (128, 39, 1, 64)  │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_5  │ (128, 17, 1, 64)  │      1,536 │ stream_4[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (128, 17, 1, 64)  │      4,096 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (128, 17, 1, 64)  │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (128, 17, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_5 (Stream)   │ (128, 17, 1, 64)  │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (128, 1088)       │          0 │ stream_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (128, 1)          │      1,089 │ flatten[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,049 (101.75 KB)
#  Trainable params: 25,537 (99.75 KB)
#  Non-trainable params: 512 (2.00 KB)
# INFO:absl:None
# INFO:absl:Step #500: rate 0.001000, accuracy 99.96%, recall 99.77%, precision 99.74%, cross entropy 0.001216
# INFO:absl:Step 500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 14, estimated false positives per hour = 1.44771, loss = 0.00034, auc = 1.00000, average viable recall = 0.973812047
# INFO:absl:Sharding callback duration: 61 microseconds
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 97.38120%; no faph cutoff is 1.00
# INFO:absl:Step #1000: rate 0.001000, accuracy 99.96%, recall 99.78%, precision 99.72%, cross entropy 0.000821
# INFO:absl:Step 1000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 34, estimated false positives per hour = 3.51586, loss = 0.00070, auc = 0.99999, average viable recall = 0.947003637
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 97.38120%; no faph cutoff is 1.00
# INFO:absl:Step #1500: rate 0.001000, accuracy 99.98%, recall 99.89%, precision 99.89%, cross entropy 0.000599
# INFO:absl:Step 1500 (nonstreaming): Validation: recall at no faph = 98.800 with cutoff 0.99, accuracy = 99.80%, recall = 99.80%, precision = 100.00%, ambient false positives = 15, estimated false positives per hour = 1.55111, loss = 0.00032, auc = 1.00000, average viable recall = 0.997027030
# INFO:absl:Sharding callback duration: 23 microseconds
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.70270%; no faph cutoff is 0.99
# INFO:absl:Step #2000: rate 0.001000, accuracy 99.99%, recall 99.94%, precision 99.98%, cross entropy 0.000242
# INFO:absl:Step 2000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 98.40%, recall = 98.40%, precision = 100.00%, ambient false positives = 18, estimated false positives per hour = 1.86134, loss = 0.00096, auc = 0.99898, average viable recall = 0.929607626
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.70270%; no faph cutoff is 0.99
# INFO:absl:Step #2500: rate 0.001000, accuracy 99.94%, recall 99.53%, precision 99.59%, cross entropy 0.001858
# INFO:absl:Step 2500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 22, estimated false positives per hour = 2.27497, loss = 0.00058, auc = 1.00000, average viable recall = 0.973708633
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.70270%; no faph cutoff is 0.99
# INFO:absl:Step #3000: rate 0.001000, accuracy 99.99%, recall 99.96%, precision 99.94%, cross entropy 0.000306
# INFO:absl:Step 3000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 21, estimated false positives per hour = 2.17156, loss = 0.00060, auc = 0.99999, average viable recall = 0.896282242
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.70270%; no faph cutoff is 0.99
# INFO:absl:Step #3500: rate 0.001000, accuracy 99.98%, recall 99.85%, precision 99.87%, cross entropy 0.000672
# INFO:absl:Step 3500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 95, estimated false positives per hour = 9.82372, loss = 0.00228, auc = 0.99998, average viable recall = 0.844526786
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.70270%; no faph cutoff is 0.99
# INFO:absl:Step #4000: rate 0.001000, accuracy 99.97%, recall 99.81%, precision 99.77%, cross entropy 0.000916
# INFO:absl:Step 4000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 99.80%, recall = 99.80%, precision = 100.00%, ambient false positives = 26, estimated false positives per hour = 2.68860, loss = 0.00073, auc = 0.99999, average viable recall = 0.939248719
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.70270%; no faph cutoff is 0.99
# INFO:absl:Step #4500: rate 0.001000, accuracy 99.95%, recall 99.71%, precision 99.63%, cross entropy 0.001551
# INFO:absl:Step 4500 (nonstreaming): Validation: recall at no faph = 100.000 with cutoff 0.79, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 7, estimated false positives per hour = 0.72385, loss = 0.00016, auc = 1.00000, average viable recall = 1.000000000
# INFO:absl:Sharding callback duration: 72 microseconds
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Step #5000: rate 0.001000, accuracy 99.99%, recall 99.94%, precision 99.89%, cross entropy 0.000394
# INFO:absl:Step 5000 (nonstreaming): Validation: recall at no faph = 97.800 with cutoff 0.99, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 2, estimated false positives per hour = 0.20682, loss = 0.00009, auc = 1.00000, average viable recall = 0.999224444
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Step #5500: rate 0.001000, accuracy 99.99%, recall 99.91%, precision 99.89%, cross entropy 0.000294
# INFO:absl:Step 5500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 29, estimated false positives per hour = 2.99882, loss = 0.00067, auc = 0.99999, average viable recall = 0.922082429
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Step #6000: rate 0.001000, accuracy 99.98%, recall 99.87%, precision 99.85%, cross entropy 0.000556
# INFO:absl:Step 6000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 54, estimated false positives per hour = 5.58401, loss = 0.00131, auc = 0.99998, average viable recall = 0.870740578
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Step #6500: rate 0.001000, accuracy 99.98%, recall 99.81%, precision 99.88%, cross entropy 0.000686
# INFO:absl:Step 6500 (nonstreaming): Validation: recall at no faph = 100.000 with cutoff 0.41, accuracy = 99.90%, recall = 99.90%, precision = 100.00%, ambient false positives = 0, estimated false positives per hour = 0.00000, loss = 0.00006, auc = 1.00000, average viable recall = 1.000000000
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Step #7000: rate 0.001000, accuracy 99.97%, recall 99.81%, precision 99.75%, cross entropy 0.001104
# INFO:absl:Step 7000 (nonstreaming): Validation: recall at no faph = 98.700 with cutoff 0.96, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 3, estimated false positives per hour = 0.31022, loss = 0.00009, auc = 1.00000, average viable recall = 0.999560522
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Step #7500: rate 0.001000, accuracy 99.98%, recall 99.87%, precision 99.92%, cross entropy 0.000583
# INFO:absl:Step 7500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 99.70%, recall = 99.70%, precision = 100.00%, ambient false positives = 6, estimated false positives per hour = 0.62045, loss = 0.00025, auc = 0.99999, average viable recall = 0.970658117
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Step #8000: rate 0.001000, accuracy 99.97%, recall 99.85%, precision 99.79%, cross entropy 0.000685
# INFO:absl:Step 8000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 99.80%, recall = 99.80%, precision = 100.00%, ambient false positives = 10, estimated false positives per hour = 1.03408, loss = 0.00028, auc = 0.99999, average viable recall = 0.970709819
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Step #8500: rate 0.001000, accuracy 99.99%, recall 99.96%, precision 99.96%, cross entropy 0.000182
# INFO:absl:Step 8500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 99.20%, recall = 99.20%, precision = 100.00%, ambient false positives = 2, estimated false positives per hour = 0.20682, loss = 0.00021, auc = 1.00000, average viable recall = 0.972235074
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Step #9000: rate 0.001000, accuracy 99.99%, recall 99.91%, precision 99.89%, cross entropy 0.000344
# INFO:absl:Step 9000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 99.00%, recall = 99.00%, precision = 100.00%, ambient false positives = 5, estimated false positives per hour = 0.51704, loss = 0.00030, auc = 0.99999, average viable recall = 0.970373753
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Step #9500: rate 0.001000, accuracy 99.96%, recall 99.75%, precision 99.77%, cross entropy 0.000963
# INFO:absl:Step 9500 (nonstreaming): Validation: recall at no faph = 98.800 with cutoff 0.94, accuracy = 99.80%, recall = 99.80%, precision = 100.00%, ambient false positives = 7, estimated false positives per hour = 0.72385, loss = 0.00016, auc = 1.00000, average viable recall = 0.998124056
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Step #10000: rate 0.001000, accuracy 99.98%, recall 99.92%, precision 99.87%, cross entropy 0.000554
# INFO:absl:Step 10000 (nonstreaming): Validation: recall at no faph = 98.900 with cutoff 0.85, accuracy = 99.50%, recall = 99.50%, precision = 100.00%, ambient false positives = 3, estimated false positives per hour = 0.31022, loss = 0.00014, auc = 1.00000, average viable recall = 0.998448898
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 100.00000%; no faph cutoff is 0.79
# INFO:absl:Sharding callback duration: 44 microseconds
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 4
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 10
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 14
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 22
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 16
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (1, 204, 40)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims_1       │ (1, 204, 1, 40)   │          0 │ input_layer_1[0]… │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_6 (Stream)   │ (1, 67, 1, 32)    │      6,400 │ expand_dims_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (1, 67, 1, 32)    │          0 │ stream_6[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_7 (Stream)   │ (1, 67, 1, 32)    │          0 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (1, 63, 1, 32)    │        192 │ stream_7[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (1, 63, 1, 64)    │      2,048 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 63, 1, 64)    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (1, 63, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_8 (Stream)   │ (1, 63, 1, 64)    │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_2     │ [(1, 63, 1, 32),  │          0 │ stream_8[0][0]    │
# │ (ChannelSplit)      │ (1, 63, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_4      │ (1, 63, 1, 32)    │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_5      │ (1, 63, 1, 32)    │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_7  │ (1, 57, 1, 32)    │        256 │ strided_keep_4[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_8  │ (1, 53, 1, 32)    │        384 │ strided_keep_5[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_4      │ (1, 53, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_5      │ (1, 53, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (1, 53, 1, 64)    │          0 │ strided_drop_4[0… │
# │ (Concatenate)       │                   │            │ strided_drop_5[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (1, 53, 1, 64)    │      4,096 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 53, 1, 64)    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (1, 53, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_9 (Stream)   │ (1, 53, 1, 64)    │          0 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_3     │ [(1, 53, 1, 32),  │          0 │ stream_9[0][0]    │
# │ (ChannelSplit)      │ (1, 53, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_6      │ (1, 53, 1, 32)    │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_7      │ (1, 53, 1, 32)    │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_9  │ (1, 45, 1, 32)    │        320 │ strided_keep_6[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_10 │ (1, 39, 1, 32)    │        512 │ strided_keep_7[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_6      │ (1, 39, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_7      │ (1, 39, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (1, 39, 1, 64)    │          0 │ strided_drop_6[0… │
# │ (Concatenate)       │                   │            │ strided_drop_7[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (1, 39, 1, 64)    │      4,096 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 39, 1, 64)    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (1, 39, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_10 (Stream)  │ (1, 39, 1, 64)    │          0 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_11 │ (1, 17, 1, 64)    │      1,536 │ stream_10[0][0]   │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (1, 17, 1, 64)    │      4,096 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 17, 1, 64)    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (1, 17, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_11 (Stream)  │ (1, 17, 1, 64)    │          0 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (1, 1088)         │          0 │ stream_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (1, 1)            │      1,089 │ flatten_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,049 (101.75 KB)
#  Trainable params: 25,537 (99.75 KB)
#  Non-trainable params: 512 (2.00 KB)
# INFO:absl:None
# INFO:absl:Saving streaming model
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 2
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 4
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 10
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 14
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 22
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 16
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_audio         │ (1, 3, 40)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims_2       │ (1, 3, 1, 40)     │          0 │ input_audio[0][0] │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_6 (Stream)   │ (1, 1, 1, 32)     │      6,480 │ expand_dims_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (1, 1, 1, 32)     │          0 │ stream_6[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_7 (Stream)   │ (1, 5, 1, 32)     │        128 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (1, 1, 1, 32)     │        192 │ stream_7[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (1, 1, 1, 64)     │      2,048 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 1, 1, 64)     │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (1, 1, 1, 64)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_8 (Stream)   │ (1, 11, 1, 64)    │        640 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_2     │ [(1, 11, 1, 32),  │          0 │ stream_8[0][0]    │
# │ (ChannelSplit)      │ (1, 11, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_4      │ (1, 7, 1, 32)     │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_5      │ (1, 11, 1, 32)    │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_7  │ (1, 1, 1, 32)     │        256 │ strided_keep_4[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_8  │ (1, 1, 1, 32)     │        384 │ strided_keep_5[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_4      │ (1, 1, 1, 32)     │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_5      │ (1, 1, 1, 32)     │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (1, 1, 1, 64)     │          0 │ strided_drop_4[0… │
# │ (Concatenate)       │                   │            │ strided_drop_5[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (1, 1, 1, 64)     │      4,096 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 1, 1, 64)     │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (1, 1, 1, 64)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_9 (Stream)   │ (1, 15, 1, 64)    │        896 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_3     │ [(1, 15, 1, 32),  │          0 │ stream_9[0][0]    │
# │ (ChannelSplit)      │ (1, 15, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_6      │ (1, 9, 1, 32)     │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_7      │ (1, 15, 1, 32)    │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_9  │ (1, 1, 1, 32)     │        320 │ strided_keep_6[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_10 │ (1, 1, 1, 32)     │        512 │ strided_keep_7[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_6      │ (1, 1, 1, 32)     │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_7      │ (1, 1, 1, 32)     │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (1, 1, 1, 64)     │          0 │ strided_drop_6[0… │
# │ (Concatenate)       │                   │            │ strided_drop_7[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (1, 1, 1, 64)     │      4,096 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 1, 1, 64)     │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (1, 1, 1, 64)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_10 (Stream)  │ (1, 23, 1, 64)    │      1,408 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_11 │ (1, 1, 1, 64)     │      1,536 │ stream_10[0][0]   │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (1, 1, 1, 64)     │      4,096 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 1, 1, 64)     │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (1, 1, 1, 64)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_11 (Stream)  │ (1, 17, 1, 64)    │      1,024 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (1, 1088)         │          0 │ stream_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (1, 1)            │      1,089 │ flatten_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,225 (118.07 KB)
#  Trainable params: 25,537 (99.75 KB)
#  Non-trainable params: 4,688 (18.31 KB)
# INFO:absl:Function `call` contains input name(s) resource with unsupported characters which will be renamed to dense_1_1_add_readvariableop_resource in the SavedModel.
# INFO:absl:Function `call` contains input name(s) resource with unsupported characters which will be renamed to dense_1_1_add_readvariableop_resource in the SavedModel.
# INFO:absl:Sharding callback duration: 36 microseconds
# INFO:absl:Sharding callback duration: 27 microseconds
# INFO:absl:Writing fingerprint to trained_models/wakeword/stream_state_internal/fingerprint.pb
# Saved artifact at 'trained_models/wakeword/stream_state_internal'. The following endpoints are available:
#
# * Endpoint 'serve'
#   inputs (POSITIONAL_OR_KEYWORD): TensorSpec(shape=(1, 3, 40), dtype=tf.float32, name=None)
#   training (POSITIONAL_OR_KEYWORD): Literal[None]
#   mask (POSITIONAL_OR_KEYWORD): Literal[None]
# Output Type:
#   TensorSpec(shape=(1, 1), dtype=tf.float32, name=None)
# Captures:
#   6103136240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6149094944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103133424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103004640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102993024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103002880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102998832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102991264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103128496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102994256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5091133920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103000592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5091142720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5091145536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5091134096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102991968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102916912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102913392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102913216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102916208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102919024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102912864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5091026800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102923776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5091018528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5091027328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090924976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090920048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090921456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090924272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090926032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090931664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090931840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090931488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090919872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090923920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090872128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090874944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090869840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090882512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5090882688: TensorSpec(shape=(), dtype=tf.resource, name=None)
# INFO:absl:Converting quantized streaming model to TFLite
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1752227793.459673 5252439 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1752227793.459843 5252439 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-07-11 11:56:33.462669: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: trained_models/wakeword/stream_state_internal
# 2025-07-11 11:56:33.463670: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-07-11 11:56:33.463677: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: trained_models/wakeword/stream_state_internal
# I0000 00:00:1752227793.474627 5252439 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# 2025-07-11 11:56:33.476949: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-07-11 11:56:33.552382: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: trained_models/wakeword/stream_state_internal
# 2025-07-11 11:56:33.576440: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 113948 microseconds.
# 2025-07-11 11:56:33.625263: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-07-11 11:56:33.751171: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:4061] Estimated count of arithmetic ops: 0.050 M  ops, equivalently 0.025 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: UINT8
# 2025-07-11 11:56:46.722178: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:4061] Estimated count of arithmetic ops: 0.050 M  ops, equivalently 0.025 M  MACs
# INFO:absl:Testing the TFLite quantized streaming model false accept per hour and false rejection rates at various cutoffs.
# UserWarning:
#         Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#         TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#         See the [migration guide](https://ai.google.dev/edge/litert/migration)
#         for details.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# INFO:absl:Testing the testing_ambient set.
# INFO:absl:Testing the testing set.
# INFO:absl:AUC 0.09374
# INFO:absl:Cutoff 0.98: frr=0.0900; faph=0.000
# INFO:absl:Cutoff 0.97: frr=0.0900; faph=0.187
# INFO:absl:Cutoff 0.86: frr=0.0600; faph=0.375
# INFO:absl:Cutoff 0.73: frr=0.0400; faph=0.562
# INFO:absl:Cutoff 0.70: frr=0.0400; faph=0.750
# INFO:absl:Cutoff 0.69: frr=0.0400; faph=0.937
# INFO:absl:Cutoff 0.60: frr=0.0400; faph=1.125
# INFO:absl:Cutoff 0.58: frr=0.0400; faph=1.312
# INFO:absl:Cutoff 0.44: frr=0.0400; faph=1.500
# INFO:absl:Cutoff 0.40: frr=0.0300; faph=1.687
# INFO:absl:Cutoff 0.27: frr=0.0300; faph=1.875
# INFO:absl:Cutoff 0.27: frr=0.0300; faph=2.000

# %%
# Downloads the tflite model file. To use on the device, you need to write a
# Model JSON file. See https://esphome.io/components/micro_wake_word for the
# documentation and
# https://github.com/esphome/micro-wake-word-models/tree/main/models/v2 for
# examples. Adjust the probability threshold based on the test results obtained
# after training is finished. You may also need to increase the Tensor arena
# model size if the model fails to load.

from google.colab import files

files.download(f"trained_models/wakeword/tflite_stream_state_internal_quant/stream_state_internal_quant.tflite")
